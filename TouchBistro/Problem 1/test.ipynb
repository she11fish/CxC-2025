# %%
import pandas as pd
import matplotlib.pyplot as plt

import dask.dataframe as dd
import numpy as np

# %%
df = pd.read_csv("./relavant.csv")
# 28.6 s
df
# Out:
#          Unnamed: 0 order_seated_at_local order_closed_at_local  \
# 0                 0   2024-07-01 09:16:15   2024-07-01 09:17:01
# 1                 1   2024-07-01 13:32:12   2024-07-01 13:37:00
# 2                 2   2024-07-01 11:17:17   2024-07-01 11:19:32
# 3                 3   2024-07-01 15:05:11   2024-07-01 15:05:59
# 4                 4   2024-07-01 12:39:17   2024-07-01 12:41:00
# ...             ...                   ...                   ...
# 8902568      167159   2024-12-29 19:19:52   2024-12-29 20:32:54
# 8902569      167160   2024-12-30 19:08:55   2024-12-30 20:36:19
# 8902570      167161   2024-12-31 14:08:20   2024-12-31 14:24:23
# 8902571      167162   2024-12-31 16:59:35   2024-12-31 17:00:34
# 8902572      167163   2024-12-31 17:05:51   2024-12-31 18:55:07
#
#          order_duration_seconds  \
# 0                            46
# 1                           288
# 2                           135
# 3                            48
# 4                           103
# ...                         ...
# 8902568                    4382
# 8902569                    5244
# 8902570                     963
# 8902571                      59
# 8902572                    6556
#
#                                                  bill_uuid  \
# 0        240701091701~4D63608F-523C-4EFF-9A4F-78D6C44B5159
# 1        240701133659~3A0BEDE2-E9E5-484D-B909-780E485F0D69
# 2        240701111931~670EEB85-E939-4924-B92F-C95076B7E930
# 3        240701150558~3D6F473E-D5EF-4BB8-AFAB-30DB2A0764C0
# 4        240701124059~0521794C-51FC-4C30-A368-995CE4DE105F
# ...                                                    ...
# 8902568  241229203254~464AA06D-F986-4C51-8A53-A7B8362072D6
# 8902569  241230203619~37348A86-98D1-4113-8EDD-06A3CF61A85B
# 8902570  241231142423~9D2E9295-9E59-4E76-8242-D230C9FD2494
# 8902571  241231170034~A9B4401D-26DC-4FC5-A4F9-0261D950DB3B
# 8902572  241231185507~62C6632E-2957-4F0D-8AFF-CF89CA378FB4
#
#                                              venue_xref_id
# 0        39e5b4830d4d9c14db7368a95b65d5463ea3d095203737...
# 1        39e5b4830d4d9c14db7368a95b65d5463ea3d095203737...
# 2        39e5b4830d4d9c14db7368a95b65d5463ea3d095203737...
# 3        39e5b4830d4d9c14db7368a95b65d5463ea3d095203737...
# 4        39e5b4830d4d9c14db7368a95b65d5463ea3d095203737...
# ...                                                    ...
# 8902568  45f1736264898588301e2983fd2de6969a9af33aa0f6f8...
# 8902569  45f1736264898588301e2983fd2de6969a9af33aa0f6f8...
# 8902570  45f1736264898588301e2983fd2de6969a9af33aa0f6f8...
# 8902571  45f1736264898588301e2983fd2de6969a9af33aa0f6f8...
# 8902572  45f1736264898588301e2983fd2de6969a9af33aa0f6f8...
#
# [8902573 rows x 6 columns]

# %%
from ydata_profiling import ProfileReport
report = ProfileReport(df)
report
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python311\Lib\multiprocessing\pool.py:856, in IMapIterator.next(self, timeout)
#     855 try:
# --> 856     item = self._items.popleft()
#     857 except IndexError:
#
# IndexError: pop from an empty deque
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 3
#       1 from ydata_profiling import ProfileReport
#       2 report = ProfileReport(df)
# ----> 3 report
#
# File c:\Users\wahee\Programs\projects\CxC-2025\TouchBistro\Problem 1\.venv\Lib\site-packages\IPython\core\displayhook.py:268, in DisplayHook.__call__(self, result)
#     266 self.start_displayhook()
#     267 self.write_output_prompt()
# --> 268 format_dict, md_dict = self.compute_format_data(result)
#     269 self.update_user_ns(result)
#     270 self.fill_exec_result(result)
#
# File c:\Users\wahee\Programs\projects\CxC-2025\TouchBistro\Problem 1\.venv\Lib\site-packages\IPython\core\displayhook.py:157, in DisplayHook.compute_format_data(self, result)
#     127 def compute_format_data(self, result):
#     128     """Compute format data of the object to be displayed.
#     129
#     130     The format data is a generalization of the :func:`repr` of an object.
#    (...)
#     155
#     156     """
# --> 157     return self.shell.display_formatter.format(result)
#
# File c:\Users\wahee\Programs\projects\CxC-2025\TouchBistro\Problem 1\.venv\Lib\site-packages\IPython\core\formatters.py:238, in DisplayFormatter.format(self, obj, include, exclude)
#     236 md = None
#     237 try:
# --> 238     data = formatter(obj)
#     239 except:
#     240     # FIXME: log the exception
#     241     raise
#
# File c:\Users\wahee\Programs\projects\CxC-2025\TouchBistro\Problem 1\.venv\Lib\site-packages\decorator.py:232, in decorate.<locals>.fun(*args, **kw)
#     230 if not kwsyntax:
#     231     args, kw = fix(args, kw, sig)
# --> 232 return caller(func, *(extras + args), **kw)
#
# File c:\Users\wahee\Programs\projects\CxC-2025\TouchBistro\Problem 1\.venv\Lib\site-packages\IPython\core\formatters.py:282, in catch_format_error(method, self, *args, **kwargs)
#     280 """show traceback on failed format call"""
#     281 try:
# --> 282     r = method(self, *args, **kwargs)
#     283 except NotImplementedError:
#     284     # don't warn on NotImplementedErrors
#     285     return self._check_return(None, args[0])
#
# File c:\Users\wahee\Programs\projects\CxC-2025\TouchBistro\Problem 1\.venv\Lib\site-packages\IPython\core\formatters.py:406, in BaseFormatter.__call__(self, obj)
#     404     method = get_real_method(obj, self.print_method)
#     405     if method is not None:
# --> 406         return method()
#     407     return None
#     408 else:
#
# File c:\Users\wahee\Programs\projects\CxC-2025\TouchBistro\Problem 1\.venv\Lib\site-packages\ydata_profiling\profile_report.py:541, in ProfileReport._repr_html_(self)
#     539 def _repr_html_(self) -> None:
#     540     """The ipython notebook widgets user interface gets called by the jupyter notebook."""
# --> 541     self.to_notebook_iframe()
#
# File c:\Users\wahee\Programs\projects\CxC-2025\TouchBistro\Problem 1\.venv\Lib\site-packages\ydata_profiling\profile_report.py:521, in ProfileReport.to_notebook_iframe(self)
#     519 with warnings.catch_warnings():
#     520     warnings.simplefilter("ignore")
# --> 521     display(get_notebook_iframe(self.config, self))
#
# File c:\Users\wahee\Programs\projects\CxC-2025\TouchBistro\Problem 1\.venv\Lib\site-packages\ydata_profiling\report\presentation\flavours\widget\notebook.py:75, in get_notebook_iframe(config, profile)
#      73     output = get_notebook_iframe_src(config, profile)
#      74 elif attribute == IframeAttribute.srcdoc:
# ---> 75     output = get_notebook_iframe_srcdoc(config, profile)
#      76 else:
#      77     raise ValueError(
#      78         f'Iframe Attribute can be "src" or "srcdoc" (current: {attribute}).'
#      79     )
#
# File c:\Users\wahee\Programs\projects\CxC-2025\TouchBistro\Problem 1\.venv\Lib\site-packages\ydata_profiling\report\presentation\flavours\widget\notebook.py:29, in get_notebook_iframe_srcdoc(config, profile)
#      27 width = config.notebook.iframe.width
#      28 height = config.notebook.iframe.height
# ---> 29 src = html.escape(profile.to_html())
#      31 iframe = f'<iframe width="{width}" height="{height}" srcdoc="{src}" frameborder="0" allowfullscreen></iframe>'
#      33 return HTML(iframe)
#
# File c:\Users\wahee\Programs\projects\CxC-2025\TouchBistro\Problem 1\.venv\Lib\site-packages\ydata_profiling\profile_report.py:491, in ProfileReport.to_html(self)
#     483 def to_html(self) -> str:
#     484     """Generate and return complete template as lengthy string
#     485         for using with frameworks.
#     486
#    (...)
#     489
#     490     """
# --> 491     return self.html
#
# File c:\Users\wahee\Programs\projects\CxC-2025\TouchBistro\Problem 1\.venv\Lib\site-packages\ydata_profiling\profile_report.py:287, in ProfileReport.html(self)
#     284 @property
#     285 def html(self) -> str:
#     286     if self._html is None:
# --> 287         self._html = self._render_html()
#     288     return self._html
#
# File c:\Users\wahee\Programs\projects\CxC-2025\TouchBistro\Problem 1\.venv\Lib\site-packages\ydata_profiling\profile_report.py:404, in ProfileReport._render_html(self)
#     401 def _render_html(self) -> str:
#     402     from ydata_profiling.report.presentation.flavours import HTMLReport
# --> 404     report = self.report
#     406     with tqdm(
#     407         total=1, desc="Render HTML", disable=not self.config.progress_bar
#     408     ) as pbar:
#     409         html = HTMLReport(copy.deepcopy(report)).render(
#     410             nav=self.config.html.navbar_show,
#     411             offline=self.config.html.use_local_assets,
#    (...)
#     419             version=self.description_set.package["ydata_profiling_version"],
#     420         )
#
# File c:\Users\wahee\Programs\projects\CxC-2025\TouchBistro\Problem 1\.venv\Lib\site-packages\ydata_profiling\profile_report.py:281, in ProfileReport.report(self)
#     278 @property
#     279 def report(self) -> Root:
#     280     if self._report is None:
# --> 281         self._report = get_report_structure(self.config, self.description_set)
#     282     return self._report
#
# File c:\Users\wahee\Programs\projects\CxC-2025\TouchBistro\Problem 1\.venv\Lib\site-packages\ydata_profiling\profile_report.py:263, in ProfileReport.description_set(self)
#     260 @property
#     261 def description_set(self) -> BaseDescription:
#     262     if self._description_set is None:
# --> 263         self._description_set = describe_df(
#     264             self.config,
#     265             self.df,
#     266             self.summarizer,
#     267             self.typeset,
#     268             self._sample,
#     269         )
#     270     return self._description_set
#
# File c:\Users\wahee\Programs\projects\CxC-2025\TouchBistro\Problem 1\.venv\Lib\site-packages\ydata_profiling\model\describe.py:74, in describe(config, df, summarizer, typeset, sample)
#      72 # Variable-specific
#      73 pbar.total += len(df.columns)
# ---> 74 series_description = get_series_descriptions(
#      75     config, df, summarizer, typeset, pbar
#      76 )
#      78 pbar.set_postfix_str("Get variable types")
#      79 pbar.total += 1
#
# File c:\Users\wahee\Programs\projects\CxC-2025\TouchBistro\Problem 1\.venv\Lib\site-packages\multimethod\__init__.py:375, in multimethod.__call__(self, *args, **kwargs)
#     373 func = self.dispatch(*args)
#     374 try:
# --> 375     return func(*args, **kwargs)
#     376 except TypeError as ex:
#     377     raise DispatchError(f"Function {func.__code__}") from ex
#
# File c:\Users\wahee\Programs\projects\CxC-2025\TouchBistro\Problem 1\.venv\Lib\site-packages\ydata_profiling\model\pandas\summary_pandas.py:112, in pandas_get_series_descriptions(config, df, summarizer, typeset, pbar)
#     109 else:
#     110     # TODO: use `Pool` for Linux-based systems
#     111     with multiprocessing.pool.ThreadPool(pool_size) as executor:
# --> 112         for i, (column, description) in enumerate(
#     113             executor.imap_unordered(multiprocess_1d, args)
#     114         ):
#     115             pbar.set_postfix_str(f"Describe variable:{column}")
#     116             series_description[column] = description
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\multiprocessing\pool.py:861, in IMapIterator.next(self, timeout)
#     859     self._pool = None
#     860     raise StopIteration from None
# --> 861 self._cond.wait(timeout)
#     862 try:
#     863     item = self._items.popleft()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\threading.py:320, in Condition.wait(self, timeout)
#     318 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     319     if timeout is None:
# --> 320         waiter.acquire()
#     321         gotit = True
#     322     else:
#
# KeyboardInterrupt:
